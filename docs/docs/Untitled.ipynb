# %%
import pandas as pd

import sweat

# %%
example = sweat.examples(path="2020-06-01-16-52-40.fit")
data = sweat.read_file(example.path)

# %%
data.sweat.mean_power()
# Out:
# 149.30526315789473

# %%
idx = pd.IndexSlice
data.loc[idx[:, :"00:00:05"], :]
# Out:
#                                      latitude  longitude  distance  \
# datetime                  relative
# 2020-06-01 14:52:40+00:00 00:00:00  622266348   53580528      6.59
# 2020-06-01 14:52:41+00:00 00:00:01  622266877   53579855     12.85
# 2020-06-01 14:52:42+00:00 00:00:02  622267407   53579166     19.18
# 2020-06-01 14:52:43+00:00 00:00:03  622267952   53578466     25.65
# 2020-06-01 14:52:44+00:00 00:00:04  622268539   53577800     32.33
# 2020-06-01 14:52:45+00:00 00:00:05  622269101   53577107     38.90
#
#                                     accumulated_power  enhanced_altitude  \
# datetime                  relative
# 2020-06-01 14:52:40+00:00 00:00:00                162              -20.2
# 2020-06-01 14:52:41+00:00 00:00:01                310              -20.0
# 2020-06-01 14:52:42+00:00 00:00:02                467              -20.0
# 2020-06-01 14:52:43+00:00 00:00:03                622              -20.0
# ...

# %%
data[:(data.index[0] + pd.Timedelta(5, unit="s"))]
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-25-4a8f49e67627> in <module>
# ----> 1 data[:(data.index[0] + pd.Timedelta(5, unit="s"))]
#
# TypeError: can only concatenate tuple (not "Timedelta") to tuple

# %%
(data.index[0][0] + pd.Timedelta(5, unit="s"))
# Out:
# Timestamp('2020-06-01 14:52:45+0000', tz='UTC')

# %%
data.index[0]
# Out:
# (Timestamp('2020-06-01 14:52:40+0000', tz='UTC'), Timedelta('0 days 00:00:00'))

# %%
data.loc[:, "00:00:05"]
# Out:
# KeyErrorTraceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '00:00:05'
#
# During handling of the above exception, another exception occurred:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-36-9e150d2e446b> in <module>
# ----> 1 data.loc[:, "00:00:05"]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...

# %%
data.loc["2020", "00:00:05"]
# Out:
# KeyErrorTraceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '00:00:05'
#
# During handling of the above exception, another exception occurred:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-57-8daa5522eabe> in <module>
# ----> 1 data.loc["2020", "00:00:05"]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...
